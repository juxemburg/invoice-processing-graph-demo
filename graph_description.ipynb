# %%
from src.invoice_agent.graph import invoice_graph, ProcessNextInvoice

invoice_graph.mermaid_code(start_node=ProcessNextInvoice)
# Out:
# '---\ntitle: invoice_graph\n---\nstateDiagram-v2\n  [*] --> ProcessNextInvoice\n  ProcessNextInvoice --> ExtractNode\n  ProcessNextInvoice --> AggregateNode\n  ExtractNode --> ValidateNode\n  ExtractNode --> ProcessNextInvoice\n  ValidateNode --> NormalizeNode\n  ValidateNode --> ProcessNextInvoice\n  NormalizeNode --> CategorizeNode\n  CategorizeNode --> ProcessNextInvoice\n  AggregateNode --> ReportNode\n  ReportNode --> [*]'

# %% [markdown]
# ## Graph diagram

# %% [markdown]
# ```mermaid
# stateDiagram-v2
#   [*] --> ProcessNextInvoice
#   ProcessNextInvoice --> ExtractNode
#   ProcessNextInvoice --> AggregateNode
#   ExtractNode --> ValidateNode
#   ExtractNode --> ProcessNextInvoice
#   ValidateNode --> NormalizeNode
#   ValidateNode --> ProcessNextInvoice
#   NormalizeNode --> CategorizeNode
#   CategorizeNode --> ProcessNextInvoice
#   AggregateNode --> ReportNode
#   ReportNode --> [*]
# ```
